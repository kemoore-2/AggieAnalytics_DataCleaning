# %%
import pandas as pd
#packege used for webscraping
import requests
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#  Go to web page
#
#  Right click and select inspect
#
#   Select Network
#
#
#   Select XHR
#   Selecy magnifying glass
#
#   Enter desired webpage name (example: leaders, standings, stats)
#
#   Click URL
#   Click Header
#
#   Click GET URL
#
#   Copy URL
#   Paste into google colab

# %%
#Test Web scrape
#texturl = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2025-26&SeasonType=Pre%20Season&StatCategory=PTS'
#r = requests.get(url=texturl).json()
#r

# %%
mens_data = '/content/drive/MyDrive/Senior Project NCAT Basketaball /NCATMensWomens_boxscore (Unzipped Files)/NCATMens_boxscore.csv'

# %%
#df = pd.read_csv(mens_data);
#df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4124939249.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(mens_data);
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %% [markdown]
# Basketball DATA CLEANING Of Mens dataset

# %%
new_column_names = df.iloc[1].tolist()
df.columns = new_column_names
df = df.drop(df.index[0])
df = df.drop(df.index[0])
df

# %%
# Detect duplicates and rename them
df.columns = [
    f"{col}_{i}" if df.columns.tolist().count(col) > 1 and col in df.columns[:i]
    else col
    for i, col in enumerate(df.columns)
]
#print(df.columns)

#column_to_rename = df.columns[4]
#df.rename(columns={column_to_rename: 'AVG_MIN'}, inplace = True)
df

# %%
#Changed name for Averge points reabounds and minutes
df.rename(columns={'AVG': 'AVG_MIN', 'AVG_14': 'AVG_REB', 'AVG_22': 'AVG_PTS'}, inplace = True)
print(df.columns)
df

# %%
divisor = 32
df['A'] = pd.to_numeric(df['A'], errors='coerce')
df['AVG_AST'] = df['A'] / divisor
#Computed the season avereage assist for each player
df.iloc[0, df.columns.get_loc('AVG_AST')] = df.iloc[0, df.columns.get_loc('A')] / 21
df.iloc[1, df.columns.get_loc('AVG_AST')] = df.iloc[1, df.columns.get_loc('A')] / 21
df.iloc[2, df.columns.get_loc('AVG_AST')] = df.iloc[2, df.columns.get_loc('A')] / 32
df.iloc[3, df.columns.get_loc('AVG_AST')] = df.iloc[3, df.columns.get_loc('A')] / 28
df.iloc[4, df.columns.get_loc('AVG_AST')] = df.iloc[4, df.columns.get_loc('A')] / 31
df.iloc[5, df.columns.get_loc('AVG_AST')] = df.iloc[5, df.columns.get_loc('A')] / 18
df.iloc[6, df.columns.get_loc('AVG_AST')] = df.iloc[6, df.columns.get_loc('A')] / 6
df.iloc[7, df.columns.get_loc('AVG_AST')] = df.iloc[7, df.columns.get_loc('A')] / 32
df.iloc[8, df.columns.get_loc('AVG_AST')] = df.iloc[8, df.columns.get_loc('A')] / 29
df.iloc[9, df.columns.get_loc('AVG_AST')] = df.iloc[9, df.columns.get_loc('A')] / 12
df.iloc[10, df.columns.get_loc('AVG_AST')] = df.iloc[10, df.columns.get_loc('A')] / 4
df.iloc[11, df.columns.get_loc('AVG_AST')] = df.iloc[11, df.columns.get_loc('A')] / 4
df.iloc[12, df.columns.get_loc('AVG_AST')] = df.iloc[12, df.columns.get_loc('A')] / 3
df

# %%
df['BLK'] = pd.to_numeric(df['BLK'], errors='coerce')
df['AVG_BLK'] = df['BLK'] / 1
df.iloc[0, df.columns.get_loc('AVG_BLK')] = df.iloc[0, df.columns.get_loc('BLK')] / 21
df.iloc[1, df.columns.get_loc('AVG_BLK')] = df.iloc[1, df.columns.get_loc('BLK')] / 21
df.iloc[2, df.columns.get_loc('AVG_BLK')] = df.iloc[2, df.columns.get_loc('BLK')] / 32
df.iloc[3, df.columns.get_loc('AVG_BLK')] = df.iloc[3, df.columns.get_loc('BLK')] / 28
df.iloc[4, df.columns.get_loc('AVG_BLK')] = df.iloc[4, df.columns.get_loc('BLK')] / 31
df.iloc[5, df.columns.get_loc('AVG_BLK')] = df.iloc[5, df.columns.get_loc('BLK')] / 18
df.iloc[6, df.columns.get_loc('AVG_BLK')] = df.iloc[6, df.columns.get_loc('BLK')] / 6
df.iloc[7, df.columns.get_loc('AVG_BLK')] = df.iloc[7, df.columns.get_loc('BLK')] / 32
df.iloc[8, df.columns.get_loc('AVG_BLK')] = df.iloc[8, df.columns.get_loc('BLK')] / 29
df.iloc[9, df.columns.get_loc('AVG_BLK')] = df.iloc[9, df.columns.get_loc('BLK')] / 12
df.iloc[10, df.columns.get_loc('AVG_BLK')] = df.iloc[10, df.columns.get_loc('BLK')] / 4
df.iloc[11, df.columns.get_loc('AVG_BLK')] = df.iloc[11, df.columns.get_loc('BLK')] / 4
df.iloc[12, df.columns.get_loc('AVG_BLK')] = df.iloc[12, df.columns.get_loc('BLK')] / 3
df

# %%
df['STL'] = pd.to_numeric(df['STL'], errors='coerce')
df['AVG_STL'] = df['STL'] / 1
df.iloc[0, df.columns.get_loc('AVG_STL')] = df.iloc[0, df.columns.get_loc('STL')] / 21
df.iloc[1, df.columns.get_loc('AVG_STL')] = df.iloc[1, df.columns.get_loc('STL')] / 21
df.iloc[2, df.columns.get_loc('AVG_STL')] = df.iloc[2, df.columns.get_loc('STL')] / 32
df.iloc[3, df.columns.get_loc('AVG_STL')] = df.iloc[3, df.columns.get_loc('STL')] / 28
df.iloc[4, df.columns.get_loc('AVG_STL')] = df.iloc[4, df.columns.get_loc('STL')] / 31
df.iloc[5, df.columns.get_loc('AVG_STL')] = df.iloc[5, df.columns.get_loc('STL')] / 18
df.iloc[6, df.columns.get_loc('AVG_STL')] = df.iloc[6, df.columns.get_loc('STL')] / 6
df.iloc[7, df.columns.get_loc('AVG_STL')] = df.iloc[7, df.columns.get_loc('STL')] / 32
df.iloc[8, df.columns.get_loc('AVG_STL')] = df.iloc[8, df.columns.get_loc('STL')] / 29
df.iloc[9, df.columns.get_loc('AVG_STL')] = df.iloc[9, df.columns.get_loc('STL')] / 12
df.iloc[10, df.columns.get_loc('AVG_STL')] = df.iloc[10, df.columns.get_loc('STL')] / 4
df.iloc[11, df.columns.get_loc('AVG_STL')] = df.iloc[11, df.columns.get_loc('STL')] / 4
df.iloc[12, df.columns.get_loc('AVG_STL')] = df.iloc[12, df.columns.get_loc('STL')] / 3
df

# %%
df['TO'] = pd.to_numeric(df['TO'], errors='coerce')
df['AVG_TO'] = df['TO'] / 1
df.iloc[0, df.columns.get_loc('AVG_TO')] = df.iloc[0, df.columns.get_loc('TO')] / 21
df.iloc[1, df.columns.get_loc('AVG_TO')] = df.iloc[1, df.columns.get_loc('TO')] / 21
df.iloc[2, df.columns.get_loc('AVG_TO')] = df.iloc[2, df.columns.get_loc('TO')] / 32
df.iloc[3, df.columns.get_loc('AVG_TO')] = df.iloc[3, df.columns.get_loc('TO')] / 28
df.iloc[4, df.columns.get_loc('AVG_TO')] = df.iloc[4, df.columns.get_loc('TO')] / 31
df.iloc[5, df.columns.get_loc('AVG_TO')] = df.iloc[5, df.columns.get_loc('TO')] / 18
df.iloc[6, df.columns.get_loc('AVG_TO')] = df.iloc[6, df.columns.get_loc('TO')] / 6
df.iloc[7, df.columns.get_loc('AVG_TO')] = df.iloc[7, df.columns.get_loc('TO')] / 32
df.iloc[8, df.columns.get_loc('AVG_TO')] = df.iloc[8, df.columns.get_loc('TO')] / 29
df.iloc[9, df.columns.get_loc('AVG_TO')] = df.iloc[9, df.columns.get_loc('TO')] / 12
df.iloc[10, df.columns.get_loc('AVG_TO')] = df.iloc[10, df.columns.get_loc('TO')] / 4
df.iloc[11, df.columns.get_loc('AVG_TO')] = df.iloc[11, df.columns.get_loc('TO')] / 4
df.iloc[12, df.columns.get_loc('AVG_TO')] = df.iloc[12, df.columns.get_loc('TO')] / 3
df

# %%
df_numeric = df.drop(df.tail(2).index)
df_numeric['AVG_PTS'].astype(float).round(2)
df_numeric['AVG_REB'].astype(float).round(2)
df_numeric['AVG_AST'].astype(float).round(2)
df_numeric['AVG_STL'].astype(float).round(2)
df_numeric['AVG_BLK'].astype(float).round(2)
df_numeric['AVG_TO'].astype(float).round(2)
#df_numeric['Total_AVG_Stats'] = df_numeric['AVG_PTS'].astype(float).round(2) + df_numeric['AVG_REB'].astype(float).round(2) + df_numeric['AVG_AST'].astype(float).round(2) + df_numeric['AVG_STL'].astype(float).round(2) + df_numeric['AVG_BLK'].astype(float).round(2) + df_numeric['AVG_TO'].astype(float).round(2)
df_numeric['Total_AVG_Stats'] = df_numeric['AVG_PTS'].astype(float).round(2) + df_numeric['AVG_REB'].astype(float).round(2) + df_numeric['AVG_AST'].astype(float).round(2) + df_numeric['AVG_STL'].astype(float).round(2) + df_numeric['AVG_BLK'].astype(float).round(2) + df_numeric['AVG_TO'].astype(float).round(2)
df_numeric

# %%
new_df = df_numeric[['AVG_MIN', 'Total_AVG_Stats','#']]
new_df.to_csv("CleanNCATMens_data.csv", index = False)

# %%
#df_numeric['AVG_REB'] = df_numeric['AVG_REB'].round(2)

# %% [markdown]
# NC A&T Womens Basketball team Advanced Basketball Statistics

# %%
womens_data = '/content/drive/MyDrive/Senior Project NCAT Basketaball /NCATMensWomens_boxscore (Unzipped Files)/NCATWomens_boxscore.csv'
df2 = pd.read_csv(womens_data);
df2

# %%
new_column_names = df2.iloc[1].tolist()
df2.columns = new_column_names
df2 = df2.drop(df2.index[0])
df2 = df2.drop(df2.index[0])
df2.columns = [
    f"{col}_{i}" if df2.columns.tolist().count(col) > 1 and col in df2.columns[:i]
    else col
    for i, col in enumerate(df2.columns)
]
#Changed name for Averge points reabounds and minutes
df2.rename(columns={'AVG': 'AVG_MIN', 'AVG_14': 'AVG_REB', 'AVG_22': 'AVG_PTS'}, inplace = True)
print(df2.columns)
divisor = 32
df2['A'] = pd.to_numeric(df2['A'], errors='coerce')
df2['AVG_AST'] = df2['A'] / divisor # Create AVG_AST for df2
#Computed the season avereage assist for each player
df2.iloc[0, df2.columns.get_loc('AVG_AST')] = df2.iloc[0, df2.columns.get_loc('A')] / 31
df2.iloc[1, df2.columns.get_loc('AVG_AST')] = df2.iloc[1, df2.columns.get_loc('A')] / 29
df2.iloc[2, df2.columns.get_loc('AVG_AST')] = df2.iloc[2, df2.columns.get_loc('A')] / 31
df2.iloc[3, df2.columns.get_loc('AVG_AST')] = df2.iloc[3, df2.columns.get_loc('A')] / 27
df2.iloc[4, df2.columns.get_loc('AVG_AST')] = df2.iloc[4, df2.columns.get_loc('A')] / 28
df2.iloc[5, df2.columns.get_loc('AVG_AST')] = df2.iloc[5, df2.columns.get_loc('A')] / 18
df2.iloc[6, df2.columns.get_loc('AVG_AST')] = df2.iloc[6, df2.columns.get_loc('A')] / 30
df2.iloc[7, df2.columns.get_loc('AVG_AST')] = df2.iloc[7, df2.columns.get_loc('A')] / 21
df2.iloc[8, df2.columns.get_loc('AVG_AST')] = df2.iloc[8, df2.columns.get_loc('A')] / 21
df2.iloc[9, df2.columns.get_loc('AVG_AST')] = df2.iloc[9, df2.columns.get_loc('A')] / 21
df2.iloc[10, df2.columns.get_loc('AVG_AST')] = df2.iloc[10, df2.columns.get_loc('A')] / 25
df2.iloc[11, df2.columns.get_loc('AVG_AST')] = df2.iloc[11, df2.columns.get_loc('A')] / 27
df2.iloc[12, df2.columns.get_loc('AVG_AST')] = df2.iloc[12, df2.columns.get_loc('A')] / 4
df2.iloc[13, df2.columns.get_loc('AVG_AST')] = df2.iloc[13, df2.columns.get_loc('A')] / 2
df2.iloc[14, df2.columns.get_loc('AVG_AST')] = df2.iloc[14, df2.columns.get_loc('A')] / 16
df2.iloc[15, df2.columns.get_loc('AVG_AST')] = df2.iloc[15, df2.columns.get_loc('A')] / 8


df2['BLK'] = pd.to_numeric(df2['BLK'], errors='coerce')
df2['AVG_BLK'] = df2['BLK'] / 1 # Create AVG_BLK for df2
df2.iloc[0, df2.columns.get_loc('AVG_BLK')] = df2.iloc[0, df2.columns.get_loc('BLK')] / 31
df2.iloc[1, df2.columns.get_loc('AVG_BLK')] = df2.iloc[1, df2.columns.get_loc('BLK')] / 29
df2.iloc[2, df2.columns.get_loc('AVG_BLK')] = df2.iloc[2, df2.columns.get_loc('BLK')] / 31
df2.iloc[3, df2.columns.get_loc('AVG_BLK')] = df2.iloc[3, df2.columns.get_loc('BLK')] / 27
df2.iloc[4, df2.columns.get_loc('AVG_BLK')] = df2.iloc[4, df2.columns.get_loc('BLK')] / 28
df2.iloc[5, df2.columns.get_loc('AVG_BLK')] = df2.iloc[5, df2.columns.get_loc('BLK')] / 18
df2.iloc[6, df2.columns.get_loc('AVG_BLK')] = df2.iloc[6, df2.columns.get_loc('BLK')] / 30
df2.iloc[7, df2.columns.get_loc('AVG_BLK')] = df2.iloc[7, df2.columns.get_loc('BLK')] / 21
df2.iloc[8, df2.columns.get_loc('AVG_BLK')] = df2.iloc[8, df2.columns.get_loc('BLK')] / 21
df2.iloc[9, df2.columns.get_loc('AVG_BLK')] = df2.iloc[9, df2.columns.get_loc('BLK')] / 21
df2.iloc[10, df2.columns.get_loc('AVG_BLK')] = df2.iloc[10, df2.columns.get_loc('BLK')] / 25
df2.iloc[11, df2.columns.get_loc('AVG_BLK')] = df2.iloc[11, df2.columns.get_loc('BLK')] / 27
df2.iloc[12, df2.columns.get_loc('AVG_BLK')] = df2.iloc[12, df2.columns.get_loc('BLK')] / 4
df2.iloc[13, df2.columns.get_loc('AVG_BLK')] = df2.iloc[13, df2.columns.get_loc('BLK')] / 2
df2.iloc[14, df2.columns.get_loc('AVG_BLK')] = df2.iloc[14, df2.columns.get_loc('BLK')] / 16
df2.iloc[15, df2.columns.get_loc('AVG_BLK')] = df2.iloc[15, df2.columns.get_loc('BLK')] / 8


df2['STL'] = pd.to_numeric(df2['STL'], errors='coerce')
df2['AVG_STL'] = df2['STL'] / 1 # Create AVG_STL for df2
df2.iloc[0, df2.columns.get_loc('AVG_STL')] = df2.iloc[0, df2.columns.get_loc('STL')] / 31
df2.iloc[1, df2.columns.get_loc('AVG_STL')] = df2.iloc[1, df2.columns.get_loc('STL')] / 29
df2.iloc[2, df2.columns.get_loc('AVG_STL')] = df2.iloc[2, df2.columns.get_loc('STL')] / 31
df2.iloc[3, df2.columns.get_loc('AVG_STL')] = df2.iloc[3, df2.columns.get_loc('STL')] / 27
df2.iloc[4, df2.columns.get_loc('AVG_STL')] = df2.iloc[4, df2.columns.get_loc('STL')] / 28
df2.iloc[5, df2.columns.get_loc('AVG_STL')] = df2.iloc[5, df2.columns.get_loc('STL')] / 18
df2.iloc[6, df2.columns.get_loc('AVG_STL')] = df2.iloc[6, df2.columns.get_loc('STL')] / 30
df2.iloc[7, df2.columns.get_loc('AVG_STL')] = df2.iloc[7, df2.columns.get_loc('STL')] / 21
df2.iloc[8, df2.columns.get_loc('AVG_STL')] = df2.iloc[8, df2.columns.get_loc('STL')] / 21
df2.iloc[9, df2.columns.get_loc('AVG_STL')] = df2.iloc[9, df2.columns.get_loc('STL')] / 21
df2.iloc[10, df2.columns.get_loc('AVG_STL')] = df2.iloc[10, df2.columns.get_loc('STL')] / 25
df2.iloc[11, df2.columns.get_loc('AVG_STL')] = df2.iloc[11, df2.columns.get_loc('STL')] / 27
df2.iloc[12, df2.columns.get_loc('AVG_STL')] = df2.iloc[12, df2.columns.get_loc('STL')] / 4
df2.iloc[13, df2.columns.get_loc('AVG_STL')] = df2.iloc[13, df2.columns.get_loc('STL')] / 2
df2.iloc[14, df2.columns.get_loc('AVG_STL')] = df2.iloc[14, df2.columns.get_loc('STL')] / 16
df2.iloc[15, df2.columns.get_loc('AVG_STL')] = df2.iloc[15, df2.columns.get_loc('STL')] / 8

df2['TO'] = pd.to_numeric(df2['TO'], errors='coerce') # Change df to df2
df2['AVG_TO'] = df2['TO'] / 1 # Create AVG_TO for df2
df2.iloc[0, df2.columns.get_loc('AVG_TO')] = df2.iloc[0, df2.columns.get_loc('TO')] / 31
df2.iloc[1, df2.columns.get_loc('AVG_TO')] = df2.iloc[1, df2.columns.get_loc('TO')] / 29
df2.iloc[2, df2.columns.get_loc('AVG_TO')] = df2.iloc[2, df2.columns.get_loc('TO')] / 31
df2.iloc[3, df2.columns.get_loc('AVG_TO')] = df2.iloc[3, df2.columns.get_loc('TO')] / 27
df2.iloc[4, df2.columns.get_loc('AVG_TO')] = df2.iloc[4, df2.columns.get_loc('TO')] / 28
df2.iloc[5, df2.columns.get_loc('AVG_TO')] = df2.iloc[5, df2.columns.get_loc('TO')] / 18
df2.iloc[6, df2.columns.get_loc('AVG_TO')] = df2.iloc[6, df2.columns.get_loc('TO')] / 30
df2.iloc[7, df2.columns.get_loc('AVG_TO')] = df2.iloc[7, df2.columns.get_loc('TO')] / 21
df2.iloc[8, df2.columns.get_loc('AVG_TO')] = df2.iloc[8, df2.columns.get_loc('TO')] / 21
df2.iloc[9, df2.columns.get_loc('AVG_TO')] = df2.iloc[9, df2.columns.get_loc('TO')] / 21
df2.iloc[10, df2.columns.get_loc('AVG_TO')] = df2.iloc[10, df2.columns.get_loc('TO')] / 25
df2.iloc[11, df2.columns.get_loc('AVG_TO')] = df2.iloc[11, df2.columns.get_loc('TO')] / 27
df2.iloc[12, df2.columns.get_loc('AVG_TO')] = df2.iloc[12, df2.columns.get_loc('TO')] / 4
df2.iloc[13, df2.columns.get_loc('AVG_TO')] = df2.iloc[13, df2.columns.get_loc('TO')] / 2
df2.iloc[14, df2.columns.get_loc('AVG_TO')] = df2.iloc[14, df2.columns.get_loc('TO')] / 16
df2.iloc[15, df2.columns.get_loc('AVG_TO')] = df2.iloc[15, df2.columns.get_loc('TO')] / 8


df2_numeric = df2.drop(df2.tail(2).index)
df2_numeric['AVG_PTS'] = df2_numeric['AVG_PTS'].astype(float).round(2)
df2_numeric['AVG_REB'] = df2_numeric['AVG_REB'].astype(float).round(2)
df2_numeric['AVG_AST'] = df2_numeric['AVG_AST'].astype(float).round(2)
df2_numeric['AVG_STL'] = df2_numeric['AVG_STL'].astype(float).round(2)
df2_numeric['AVG_BLK'] = df2_numeric['AVG_BLK'].astype(float).round(2)
df2_numeric['AVG_TO'] = df2_numeric['AVG_TO'].astype(float).round(2)
#df_numeric['Total_AVG_Stats'] = df_numeric['AVG_PTS'].astype(float).round(2) + df_numeric['AVG_REB'].astype(float).round(2) + df_numeric['AVG_AST'].astype(float).round(2) + df_numeric['AVG_STL'].astype(float).round(2) + df_numeric['AVG_BLK'].astype(float).round(2) + df_numeric['AVG_TO'].astype(float).round(2)
df2_numeric['Total_AVG_Stats'] = df2_numeric['AVG_PTS'].astype(float).round(2) + df2_numeric['AVG_REB'].astype(float).round(2) + df2_numeric['AVG_AST'].astype(float).round(2) + df2_numeric['AVG_STL'].astype(float).round(2) + df2_numeric['AVG_BLK'].astype(float).round(2) + df2_numeric['AVG_TO'].astype(float).round(2)
df2_numeric
#new_df = df2_numeric[['AVG_MIN', 'Total_AVG_Stats','#']]
#new_df.to_csv("CleanNCATMens_data.csv", index = False)

# %%
# !pip install requests beautifulsoup4 lxml pandas

# %%
mengame1_data = '/content/drive/MyDrive/Senior Project NCAT Basketaball /NCATMenswomens_gameboxscore (Unzipped Files)/Men_game1_11-10.csv'
df3 = pd.read_csv(mengame1_data);
df3

# %%
df3 = df3.drop(df3.tail(17).index)
df3

# %%
mengame1_2_data = '/content/drive/MyDrive/Senior Project NCAT Basketaball /Menwomensgame1-2_boxscore (Unzipped Files)/Mensgame1-2_boxscore.csv'
df4 = pd.read_csv(mengame1_2_data);
df4

# %%
new_column_names = df4.iloc[1].tolist()
df4.columns = new_column_names
df4 = df4.drop(df4.index[0])
df4 = df4.drop(df4.index[0])
df4.columns = [
    f"{col}_{i}" if df4.columns.tolist().count(col) > 1 and col in df4.columns[:i]
    else col
    for i, col in enumerate(df4.columns)
]
#Changed name for Averge points reabounds and minutes
df4.rename(columns={'AVG': 'AVG_MIN', 'AVG_14': 'AVG_REB', 'AVG_22': 'AVG_PTS'}, inplace = True)
print(df4.columns)
divisor = 32
df4['A'] = pd.to_numeric(df4['A'], errors='coerce')
df4['AVG_AST'] = df4['A'] / divisor # Create AVG_AST for df2
#Computed the season avereage assist for each player
df4.iloc[0, df4.columns.get_loc('AVG_AST')] = df4.iloc[0, df4.columns.get_loc('A')] / 2
df4.iloc[1, df4.columns.get_loc('AVG_AST')] = df4.iloc[1, df4.columns.get_loc('A')] / 2
df4.iloc[2, df4.columns.get_loc('AVG_AST')] = df4.iloc[2, df4.columns.get_loc('A')] / 2
df4.iloc[3, df4.columns.get_loc('AVG_AST')] = df4.iloc[3, df4.columns.get_loc('A')] / 2
df4.iloc[4, df4.columns.get_loc('AVG_AST')] = df4.iloc[4, df4.columns.get_loc('A')] / 2
df4.iloc[5, df4.columns.get_loc('AVG_AST')] = df4.iloc[5, df4.columns.get_loc('A')] / 2
df4.iloc[6, df4.columns.get_loc('AVG_AST')] = df4.iloc[6, df4.columns.get_loc('A')] / 2
df4.iloc[7, df4.columns.get_loc('AVG_AST')] = df4.iloc[7, df4.columns.get_loc('A')] / 2
df4.iloc[8, df4.columns.get_loc('AVG_AST')] = df4.iloc[8, df4.columns.get_loc('A')] / 2
df4.iloc[9, df4.columns.get_loc('AVG_AST')] = df4.iloc[9, df4.columns.get_loc('A')] / 1
df4.iloc[10, df4.columns.get_loc('AVG_AST')] = df4.iloc[10, df4.columns.get_loc('A')] / 2
df4.iloc[11, df4.columns.get_loc('AVG_AST')] = df4.iloc[11, df4.columns.get_loc('A')] / 1

df4['BLK'] = pd.to_numeric(df4['BLK'], errors='coerce')
df4['AVG_BLK'] = df4['BLK'] / 1 # Create AVG_BLK for df2
df4.iloc[0, df4.columns.get_loc('AVG_BLK')] = df4.iloc[0, df4.columns.get_loc('BLK')] / 2
df4.iloc[1, df4.columns.get_loc('AVG_BLK')] = df4.iloc[1, df4.columns.get_loc('BLK')] / 2
df4.iloc[2, df4.columns.get_loc('AVG_BLK')] = df4.iloc[2, df4.columns.get_loc('BLK')] / 2
df4.iloc[3, df4.columns.get_loc('AVG_BLK')] = df4.iloc[3, df4.columns.get_loc('BLK')] / 2
df4.iloc[4, df4.columns.get_loc('AVG_BLK')] = df4.iloc[4, df4.columns.get_loc('BLK')] / 2
df4.iloc[5, df4.columns.get_loc('AVG_BLK')] = df4.iloc[5, df4.columns.get_loc('BLK')] / 2
df4.iloc[6, df4.columns.get_loc('AVG_BLK')] = df4.iloc[6, df4.columns.get_loc('BLK')] / 2
df4.iloc[7, df4.columns.get_loc('AVG_BLK')] = df4.iloc[7, df4.columns.get_loc('BLK')] / 2
df4.iloc[8, df4.columns.get_loc('AVG_BLK')] = df4.iloc[8, df4.columns.get_loc('BLK')] / 2
df4.iloc[9, df4.columns.get_loc('AVG_BLK')] = df4.iloc[9, df4.columns.get_loc('BLK')] / 1
df4.iloc[10, df4.columns.get_loc('AVG_BLK')] = df4.iloc[10, df4.columns.get_loc('BLK')] / 2
df4.iloc[11, df4.columns.get_loc('AVG_BLK')] = df4.iloc[11, df4.columns.get_loc('BLK')] / 1

df4['STL'] = pd.to_numeric(df4['STL'], errors='coerce')
df4['AVG_STL'] = df2['STL'] / 1 # Create AVG_STL for df2
df4.iloc[0, df4.columns.get_loc('AVG_STL')] = df4.iloc[0, df4.columns.get_loc('STL')] / 2
df4.iloc[1, df4.columns.get_loc('AVG_STL')] = df4.iloc[1, df4.columns.get_loc('STL')] / 2
df4.iloc[2, df4.columns.get_loc('AVG_STL')] = df4.iloc[2, df4.columns.get_loc('STL')] / 2
df4.iloc[3, df4.columns.get_loc('AVG_STL')] = df4.iloc[3, df4.columns.get_loc('STL')] / 2
df4.iloc[4, df4.columns.get_loc('AVG_STL')] = df4.iloc[4, df4.columns.get_loc('STL')] / 2
df4.iloc[5, df4.columns.get_loc('AVG_STL')] = df4.iloc[5, df4.columns.get_loc('STL')] / 2
df4.iloc[6, df4.columns.get_loc('AVG_STL')] = df4.iloc[6, df4.columns.get_loc('STL')] / 2
df4.iloc[7, df4.columns.get_loc('AVG_STL')] = df4.iloc[7, df4.columns.get_loc('STL')] / 2
df4.iloc[8, df4.columns.get_loc('AVG_STL')] = df4.iloc[8, df4.columns.get_loc('STL')] / 2
df4.iloc[9, df4.columns.get_loc('AVG_STL')] = df4.iloc[9, df4.columns.get_loc('STL')] / 1
df4.iloc[10, df4.columns.get_loc('AVG_STL')] = df4.iloc[10, df4.columns.get_loc('STL')] / 2
df4.iloc[11, df4.columns.get_loc('AVG_STL')] = df4.iloc[11, df4.columns.get_loc('STL')] / 1

df4['TO'] = pd.to_numeric(df4['TO'], errors='coerce') # Change df to df2
df4['AVG_TO'] = df4['TO'] / 1 # Create AVG_TO for df2
df4.iloc[0, df4.columns.get_loc('AVG_TO')] = df4.iloc[0, df4.columns.get_loc('TO')] / 2
df4.iloc[1, df4.columns.get_loc('AVG_TO')] = df4.iloc[1, df4.columns.get_loc('TO')] / 2
df4.iloc[2, df4.columns.get_loc('AVG_TO')] = df4.iloc[2, df4.columns.get_loc('TO')] / 2
df4.iloc[3, df4.columns.get_loc('AVG_TO')] = df4.iloc[3, df4.columns.get_loc('TO')] / 2
df4.iloc[4, df4.columns.get_loc('AVG_TO')] = df4.iloc[4, df4.columns.get_loc('TO')] / 2
df4.iloc[5, df4.columns.get_loc('AVG_TO')] = df4.iloc[5, df4.columns.get_loc('TO')] / 2
df4.iloc[6, df4.columns.get_loc('AVG_TO')] = df4.iloc[6, df4.columns.get_loc('TO')] / 2
df4.iloc[7, df4.columns.get_loc('AVG_TO')] = df4.iloc[7, df4.columns.get_loc('TO')] / 2
df4.iloc[8, df4.columns.get_loc('AVG_TO')] = df4.iloc[8, df4.columns.get_loc('TO')] / 2
df4.iloc[9, df4.columns.get_loc('AVG_TO')] = df4.iloc[9, df4.columns.get_loc('TO')] / 1
df4.iloc[10, df4.columns.get_loc('AVG_TO')] = df4.iloc[10, df4.columns.get_loc('TO')] / 2
df4.iloc[11, df4.columns.get_loc('AVG_TO')] = df4.iloc[11, df4.columns.get_loc('TO')] / 1

df4_numeric = df4.drop(df4.tail(2).index)
df4_numeric['AVG_PTS'] = df4_numeric['AVG_PTS'].astype(float).round(2)
df4_numeric['AVG_REB'] = df4_numeric['AVG_REB'].astype(float).round(2)
df4_numeric['AVG_AST'] = df4_numeric['AVG_AST'].astype(float).round(2)
df4_numeric['AVG_STL'] = df4_numeric['AVG_STL'].astype(float).round(2)
df4_numeric['AVG_BLK'] = df4_numeric['AVG_BLK'].astype(float).round(2)
df4_numeric['AVG_TO'] = df4_numeric['AVG_TO'].astype(float).round(2)
#df_numeric['Total_AVG_Stats'] = df_numeric['AVG_PTS'].astype(float).round(2) + df_numeric['AVG_REB'].astype(float).round(2) + df_numeric['AVG_AST'].astype(float).round(2) + df_numeric['AVG_STL'].astype(float).round(2) + df_numeric['AVG_BLK'].astype(float).round(2) + df_numeric['AVG_TO'].astype(float).round(2)
df4_numeric['Total_AVG_Stats'] = df4_numeric['AVG_PTS'].astype(float).round(2) + df4_numeric['AVG_REB'].astype(float).round(2) + df4_numeric['AVG_AST'].astype(float).round(2) + df4_numeric['AVG_STL'].astype(float).round(2) + df4_numeric['AVG_BLK'].astype(float).round(2) + df4_numeric['AVG_TO'].astype(float).round(2)
df4_numeric

# %%
import numpy as np

# Create a copy to avoid SettingWithCopyWarning if df4_numeric is a slice
df4_numeric = df4_numeric.copy()

# Handle potential division by zero by replacing 0 with NaN in 'AVG_TO'
df4_numeric['AVG_TO_cleaned'] = df4_numeric['AVG_TO'].replace(0, np.nan)

# Create the new column 'AST_TO_RATIO'
df4_numeric['AST_TO_RATIO'] = df4_numeric['AVG_AST'] / df4_numeric['AVG_TO_cleaned']

# Drop the temporary cleaned column if desired
df4_numeric = df4_numeric.drop(columns=['AVG_TO_cleaned'])

df4_numeric

# %%
new_df4 = df4_numeric[['AVG_MIN', 'Total_AVG_Stats','#','AVG_PTS','AVG_REB','AVG_AST','AVG_STL','AVG_BLK','AVG_TO','AST_TO_RATIO']]
#new_df = df2_numeric[['AVG_MIN', 'Total_AVG_Stats','#
new_df4.to_csv("CleanNCATMensgame1_2_data.csv", index = False)
df4_numeric = df4_numeric.fillna(1)
df4_numeric.to_csv("CleanNCATMensgame1_2full.csv", index = False)
df4_numeric
